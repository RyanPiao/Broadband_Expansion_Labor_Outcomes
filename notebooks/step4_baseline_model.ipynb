# %% [markdown]
# # Step 4 Baseline Model Notebook
#
# Baseline FE and event-study diagnostics.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..').resolve()
pd.read_csv(ROOT/'outputs'/'day4_baseline_model_results.csv')

# %%
pd.read_csv(ROOT/'outputs'/'day4_event_study_results.csv').head()
